# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\aditya.raas\Desktop\finaldata.csv')

# %%
df.head()
# Out:
#        Data     T    TM   Tm     SLP    H    V   VV    Vm   PM2.5
# 0  1/1/2016  16.9  25.1  6.6  1021.3   65  1.1    2   7.6  411.87
# 1  1/2/2016  15.5  24.1  7.7    1021   71  1.1  3.5  11.1   288.2
# 2  1/3/2016  14.9  22.8    8  1018.4   73  1.1  5.9    13  392.96
# 3  1/4/2016   NaN   NaN  NaN     NaN  NaN  NaN  NaN   NaN  436.37
# 4  1/5/2016   NaN   NaN  NaN     NaN  NaN  NaN  NaN   NaN  324.11

# %%
df.shape
# Out:
# (1828, 10)

# %%
df=df[df['T']!="-"]
df=df[df['TM']!="-"]
df=df[df['Tm']!="-"]
df=df[df['SLP']!="-"]
df=df[df['H']!="-"]
df=df[df['V']!="-"]
df=df[df['VV']!="-"]
df=df[df['Vm']!="-"]
df=df[df['PM2.5']!="-"]

# %%
df['Tm']= df['Tm'].str.extract('(\d+)').astype(float)
df['TM']= df['TM'].str.extract('(\d+)').astype(float)
df['SLP']= df['SLP'].str.extract('(\d+)').astype(float)
df['H']= df['H'].str.extract('(\d+)').astype(float)
df['V']= df['V'].str.extract('(\d+)').astype(float)
df['VV']= df['VV'].str.extract('(\d+)').astype(float)
df['Vm']= df['Vm'].str.extract('(\d+)').astype(float)
df['PM2.5']= df['PM2.5'].str.extract('(\d+)').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-318-1feffafc2b08> in <module>
# ----> 1 df['Tm']= df['Tm'].str.extract('(\d+)').astype(float)
#       2 df['TM']= df['TM'].str.extract('(\d+)').astype(float)
#       3 df['SLP']= df['SLP'].str.extract('(\d+)').astype(float)
#       4 df['H']= df['H'].str.extract('(\d+)').astype(float)
#       5 df['V']= df['V'].str.extract('(\d+)').astype(float)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
# ...

# %%
df['T']= df['T'].str.extract('(\d+)').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-319-9995ca18afc0> in <module>
# ----> 1 df['T']= df['T'].str.extract('(\d+)').astype(float)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 898 entries, 0 to 1822
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Data    898 non-null    object
#  1   T       898 non-null    float64
#  2   TM      898 non-null    float64
#  3   Tm      898 non-null    float64
#  4   SLP     898 non-null    float64
#  5   H       898 non-null    float64
#  6   V       898 non-null    float64
#  7   VV      898 non-null    float64
#  8   Vm      898 non-null    float64
#  9   PM2.5   792 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 77.2+ KB

# %%
nan_value = float("NaN")
#Convert NaN values to empty string

df.replace("", nan_value, inplace=True)

df.dropna(subset = ['T'], inplace=True)

# %%
nad_value = float("-")
#Convert NaN values to empty string

df.replace("", nad_value, inplace=True)

df.dropna(subset = ['T'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-322-50db3cc24dd2> in <module>
# ----> 1 nad_value = float("-")
#       2 #Convert NaN values to empty string
#       3
#       4 df.replace("", nad_value, inplace=True)
#       5
#
# ValueError: could not convert string to float: '-'

# %%
df['T'].unique()
# Out:
# array([16., 15., 14., 18., 13., 12., 11., 17., 23., 20., 22., 25., 24.,
#        26., 27., 29., 30., 32., 33., 31., 34., 38., 35., 37., 36., 28.,
#        21., 19.,  1., 10.,  8.])

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             Data     T    TM    Tm     SLP     H    V   VV    Vm  PM2.5
# 0       1/1/2016  16.0  25.0   6.0  1021.0  65.0  1.0  2.0   7.0  411.0
# 1       1/2/2016  15.0  24.0   7.0  1021.0  71.0  1.0  3.0  11.0  288.0
# 2       1/3/2016  14.0  22.0   8.0  1018.0  73.0  1.0  5.0  13.0  392.0
# 6       1/7/2016  18.0  24.0  11.0  1018.0  85.0  0.0  1.0   7.0  411.0
# 7       1/8/2016  16.0  24.0  12.0  1017.0  82.0  0.0  8.0  13.0  283.0
# ...          ...   ...   ...   ...     ...   ...  ...  ...   ...    ...
# 1815  12/20/2020  12.0  21.0   3.0  1019.0  70.0  1.0  5.0  14.0  170.0
# 1816  12/21/2020  13.0  23.0   5.0  1017.0  69.0  1.0  4.0  13.0  200.0
# 1820  12/25/2020  13.0  23.0   4.0  1017.0  74.0  1.0  3.0   9.0  253.0
# 1821  12/26/2020  13.0  22.0   4.0  1016.0  72.0  1.0  5.0   9.0  290.0
# 1822  12/27/2020  15.0  21.0   6.0  1013.0  68.0  1.0  5.0  11.0  305.0
#
# [898 rows x 10 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 898 entries, 0 to 1822
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Data    898 non-null    object
#  1   T       898 non-null    float64
#  2   TM      898 non-null    float64
#  3   Tm      898 non-null    float64
#  4   SLP     898 non-null    float64
#  5   H       898 non-null    float64
#  6   V       898 non-null    float64
#  7   VV      898 non-null    float64
#  8   Vm      898 non-null    float64
#  9   PM2.5   792 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 77.2+ KB

# %%
df['T']= df['T'].str.extract('(\d+)').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-326-9995ca18afc0> in <module>
# ----> 1 df['T']= df['T'].str.extract('(\d+)').astype(float)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 898 entries, 0 to 1822
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Data    898 non-null    object
#  1   T       898 non-null    float64
#  2   TM      898 non-null    float64
#  3   Tm      898 non-null    float64
#  4   SLP     898 non-null    float64
#  5   H       898 non-null    float64
#  6   V       898 non-null    float64
#  7   VV      898 non-null    float64
#  8   Vm      898 non-null    float64
#  9   PM2.5   792 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 77.2+ KB

# %%
df.tail()
# Out:
#             Data     T    TM   Tm     SLP     H    V   VV    Vm  PM2.5
# 1815  12/20/2020  12.0  21.0  3.0  1019.0  70.0  1.0  5.0  14.0  170.0
# 1816  12/21/2020  13.0  23.0  5.0  1017.0  69.0  1.0  4.0  13.0  200.0
# 1820  12/25/2020  13.0  23.0  4.0  1017.0  74.0  1.0  3.0   9.0  253.0
# 1821  12/26/2020  13.0  22.0  4.0  1016.0  72.0  1.0  5.0   9.0  290.0
# 1822  12/27/2020  15.0  21.0  6.0  1013.0  68.0  1.0  5.0  11.0  305.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.dropna()
# Out:
#             Data     T    TM    Tm     SLP     H    V   VV    Vm  PM2.5
# 0       1/1/2016  16.0  25.0   6.0  1021.0  65.0  1.0  2.0   7.0  411.0
# 1       1/2/2016  15.0  24.0   7.0  1021.0  71.0  1.0  3.0  11.0  288.0
# 2       1/3/2016  14.0  22.0   8.0  1018.0  73.0  1.0  5.0  13.0  392.0
# 6       1/7/2016  18.0  24.0  11.0  1018.0  85.0  0.0  1.0   7.0  411.0
# 7       1/8/2016  16.0  24.0  12.0  1017.0  82.0  0.0  8.0  13.0  283.0
# ...          ...   ...   ...   ...     ...   ...  ...  ...   ...    ...
# 1815  12/20/2020  12.0  21.0   3.0  1019.0  70.0  1.0  5.0  14.0  170.0
# 1816  12/21/2020  13.0  23.0   5.0  1017.0  69.0  1.0  4.0  13.0  200.0
# 1820  12/25/2020  13.0  23.0   4.0  1017.0  74.0  1.0  3.0   9.0  253.0
# 1821  12/26/2020  13.0  22.0   4.0  1016.0  72.0  1.0  5.0   9.0  290.0
# 1822  12/27/2020  15.0  21.0   6.0  1013.0  68.0  1.0  5.0  11.0  305.0
#
# [792 rows x 10 columns]

# %%
df=df.dropna()

# %%
X=df.iloc[:,1:9]
Y=df.iloc[:,-1]

# %%
X
# Out:
#          T    TM    Tm     SLP     H    V   VV    Vm
# 0     16.0  25.0   6.0  1021.0  65.0  1.0  2.0   7.0
# 1     15.0  24.0   7.0  1021.0  71.0  1.0  3.0  11.0
# 2     14.0  22.0   8.0  1018.0  73.0  1.0  5.0  13.0
# 6     18.0  24.0  11.0  1018.0  85.0  0.0  1.0   7.0
# 7     16.0  24.0  12.0  1017.0  82.0  0.0  8.0  13.0
# ...    ...   ...   ...     ...   ...  ...  ...   ...
# 1815  12.0  21.0   3.0  1019.0  70.0  1.0  5.0  14.0
# 1816  13.0  23.0   5.0  1017.0  69.0  1.0  4.0  13.0
# 1820  13.0  23.0   4.0  1017.0  74.0  1.0  3.0   9.0
# 1821  13.0  22.0   4.0  1016.0  72.0  1.0  5.0   9.0
# 1822  15.0  21.0   6.0  1013.0  68.0  1.0  5.0  11.0
#
# [792 rows x 8 columns]

# %%
df.shape
# Out:
# (792, 10)

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#               T        TM        Tm       SLP         H         V        VV  \
# T      1.000000  0.965394  0.955384 -0.078606 -0.545199  0.643947  0.304195
# TM     0.965394  1.000000  0.893527 -0.022222 -0.620081  0.623879  0.275487
# Tm     0.955384  0.893527  1.000000 -0.118964 -0.340129  0.559683  0.321843
# SLP   -0.078606 -0.022222 -0.118964  1.000000  0.011874 -0.043729 -0.007361
# H     -0.545199 -0.620081 -0.340129  0.011874  1.000000 -0.507305 -0.275729
# V      0.643947  0.623879  0.559683 -0.043729 -0.507305  1.000000  0.316297
# VV     0.304195  0.275487  0.321843 -0.007361 -0.275729  0.316297  1.000000
# Vm     0.252134  0.257800  0.241670 -0.005064 -0.313776  0.248382  0.805385
# PM2.5 -0.521541 -0.444394 -0.579379  0.041942  0.082604 -0.578976 -0.349233
#
#              Vm     PM2.5
# T      0.252134 -0.521541
# TM     0.257800 -0.444394
# Tm     0.241670 -0.579379
# SLP   -0.005064  0.041942
# H     -0.313776  0.082604
# V      0.248382 -0.578976
# ...

# %%
Y
# Out:
# 0       411.0
# 1       288.0
# 2       392.0
# 6       411.0
# 7       283.0
#         ...
# 1815    170.0
# 1816    200.0
# 1820    253.0
# 1821    290.0
# 1822    305.0
# Name: PM2.5, Length: 792, dtype: float64

# %%
df
# Out:
#             Data     T    TM    Tm     SLP     H    V   VV    Vm  PM2.5
# 0       1/1/2016  16.0  25.0   6.0  1021.0  65.0  1.0  2.0   7.0  411.0
# 1       1/2/2016  15.0  24.0   7.0  1021.0  71.0  1.0  3.0  11.0  288.0
# 2       1/3/2016  14.0  22.0   8.0  1018.0  73.0  1.0  5.0  13.0  392.0
# 6       1/7/2016  18.0  24.0  11.0  1018.0  85.0  0.0  1.0   7.0  411.0
# 7       1/8/2016  16.0  24.0  12.0  1017.0  82.0  0.0  8.0  13.0  283.0
# ...          ...   ...   ...   ...     ...   ...  ...  ...   ...    ...
# 1815  12/20/2020  12.0  21.0   3.0  1019.0  70.0  1.0  5.0  14.0  170.0
# 1816  12/21/2020  13.0  23.0   5.0  1017.0  69.0  1.0  4.0  13.0  200.0
# 1820  12/25/2020  13.0  23.0   4.0  1017.0  74.0  1.0  3.0   9.0  253.0
# 1821  12/26/2020  13.0  22.0   4.0  1016.0  72.0  1.0  5.0   9.0  290.0
# 1822  12/27/2020  15.0  21.0   6.0  1013.0  68.0  1.0  5.0  11.0  305.0
#
# [792 rows x 10 columns]

# %%
import seaborn as sns
corrmat=df.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(15,15))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 792 entries, 0 to 1822
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Data    792 non-null    object
#  1   T       792 non-null    float64
#  2   TM      792 non-null    float64
#  3   Tm      792 non-null    float64
#  4   SLP     792 non-null    float64
#  5   H       792 non-null    float64
#  6   V       792 non-null    float64
#  7   VV      792 non-null    float64
#  8   Vm      792 non-null    float64
#  9   PM2.5   792 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 68.1+ KB

# %%
df['T']=df['T'].astype(float)
# Out:
# <ipython-input-344-b45b585f95c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['T']=df['T'].astype(float)

# %%
print("coefficient of determination R^2<--on train set: {}".format(regressor.score(X_train,Y_train)))
print("coefficient of determination R^2<--on test set: {}".format(regressor.score(X_test,Y_test)))



from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,Y,cv=5)
score.mean()
# Out:
# coefficient of determination R^2<--on train set: 0.5197945909947784
# coefficient of determination R^2<--on test set: 0.5660949719724369
# -0.83626247055047

# %%
regressor.intercept_
# Out:
# 383.3410912725516

# %%
regressor.coef_
# Out:
# array([  3.68796657,   3.6411809 , -10.05902018,  -0.13379976,
#         -0.85579988, -48.42850509,  -3.20489581,  -0.16706414])

# %% [markdown]
# decision tree regressor

# %%
from sklearn import metrics

# %%
coeff_df=pd.DataFrame(regressor.coef_,X.columns,columns=["coefficient"])
coeff_df
# Out:
#      coefficient
# T       3.687967
# TM      3.641181
# Tm    -10.059020
# SLP    -0.133800
# H      -0.855800
# V     -48.428505
# VV     -3.204896
# Vm     -0.167064

# %%
prediction=regressor.predict(X_test)

# %%
prediction=regressor.predict(X_test)

# %%
sns.distplot(Y_test-prediction)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PM2.5', ylabel='Density'>

# %%
plt.scatter(Y_test,prediction)

# %%
print('MAE:', metrics.mean_absolute_error(Y_test, prediction))
print('MSE:', metrics.mean_squared_error(Y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, prediction)))
# Out:
# MAE: 43.70520149512761
# MSE: 3867.6995715902212
# RMSE: 62.19083189337655

# %%
from sklearn.tree import DecisionTreeRegressor
dtree=DecisionTreeRegressor(criterion="mse")

# %%
dtree.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
print("coefficient of determination R^2,--on train set:{}".format(dtree.score(X_train,Y_train)))
# Out:
# coefficient of determination R^2,--on train set:1.0

# %%
print("coefficient of determination R^2,--on test set:{}".format(dtree.score(X_test,Y_test)))
# Out:
# coefficient of determination R^2,--on test set:-0.0071857197889837465

# %%
print('MAE:', metrics.mean_absolute_error(Y_test, prediction))
print('MSE:', metrics.mean_squared_error(Y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, prediction)))
# Out:
# MAE: 48.12464985994397
# MSE: 4654.133986928105
# RMSE: 68.2212136137148

# %%
score=cross_val_score(dtree,X,Y,cv=5)
score.mean()
# Out:
# 0.03715056177264462

# %%
prediction=dtree.predict(X_test)

# %%
sns.displot(Y_test-prediction)

# %%
plt.scatter(Y_test,prediction)

# %%
DecisionTreeRegressor()
# Out:
# DecisionTreeRegressor()

# %%
params={
 "splitter"    : ["best","random"] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_samples_leaf" : [ 1,2,3,4,5 ],
"min_weight_fraction_leaf":[0.1,0.2,0.3,0.4],
 "max_features" : ["auto","log2","sqrt",None ],
    "max_leaf_nodes":[None,10,20,30,40,50,60,70]
    
}

# %%
## Hyperparameter optimization using GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
random_search=GridSearchCV(dtree,param_grid=params,scoring='neg_mean_squared_error',n_jobs=-1,cv=10,verbose=3)

# %%
random_search=GridSearchCV(dtree,param_grid=params,scoring='neg_mean_squared_error',n_jobs=-1,cv=10,verbose=3)

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
from datetime import datetime
# Here we go
start_time = timer(None) # timing starts from this point for "start_time" variable
random_search.fit(X,Y)
timer(start_time) # timing ends here for "start_time" variable
# Out:
# Fitting 10 folds for each of 10240 candidates, totalling 102400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 572 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1852 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 3644 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 5948 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 8764 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 12092 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 15932 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 20284 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 25148 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 30524 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 36412 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 42812 tasks      | elapsed:  6.2min
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor=RandomForestRegressor()

# %%
regressor.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
print("coefficient of determination R^2 <--on train set:{}.".format(regressor.score(X_train,Y_train)))
# Out:
# coefficient of determination R^2 <--on train set:0.9456061301574368.

# %%
print("coefficient of determination R^2 <--on test set:{}.".format(regressor.score(X_test,Y_test)))
# Out:
# coefficient of determination R^2 <--on test set:0.6208329981855197.

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,Y,cv=5)

# %%
print('MAE:', metrics.mean_absolute_error(Y_test, prediction))
print('MSE:', metrics.mean_squared_error(Y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, prediction)))
# Out:
# MAE: 58.4327731092437
# MSE: 8977.752100840336
# RMSE: 94.75100052685637

# %%
score.mean()
# Out:
# 0.48905979520511805

# %% [markdown]
# model prediction

# %%
prediction=regressor.predict(X_test)

# %%
sns.distplot(Y_test-prediction)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PM2.5', ylabel='Density'>

# %%
plt.scatter(Y_test,prediction)

# %% [markdown]
# # hyperparameter tuning

# %%
RandomForestRegressor()
# Out:
# RandomForestRegressor()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
n_estimators=[int(x) for x in np.linspace(start=100,stop=600,num=12)]
print(n_estimators)
# Out:
# [100, 145, 190, 236, 281, 327, 372, 418, 463, 509, 554, 600]

# %%
#randomized Search CV

#number of trees in random forest
n_estimators=[int(x) for x in np.linspace(start=100,stop=1200,num=12)]
#number of features to consider at every split
max_features=['auto','sqrt']
#maximum number of levels in tree
max_depth=[int(x) for x in np.linspace(5,30,num=6)]
#max_depth.append(none)
#minimum number of samplesrequired to split a node
min_sample_split=[2,5,10,15,100]
#minimum number of samples required at each leaf node

min_sample_leaf=[1,2,5,10]
#method of selecting samples for training each tree
#bootstrap=[trur,false]

# %%
#create the random grid
random_grid={'n_estimators': n_estimators,
            'max_features': max_features,
            'max_depth': max_depth,
            'min_sample_split': min_sample_split,
            'min_sample_split': min_sample_split}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_sample_split': [2, 5, 10, 15, 100]}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] n_estimators=500, min_sample_split=15, max_features=sqrt, max_depth=15
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-384-571606fb0d0a> in <module>
# ----> 1 rf_random.fit(X_train,Y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# ...

# %% [markdown]
# # KNN REGRESSOR

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
regressor=KNeighborsRegressor(n_neighbors=3)
regressor.fit(X_train,Y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, Y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.6417014589815295

# %%
 print("Coefficient of determination R^2 <-- on trai{}".format(regressor.score(X_test, Y_test)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.4238606133173983

# %%
prediction=regressor.predict(X_test)

# %%
sns.distplot(Y_test-prediction)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PM2.5', ylabel='Density'>

# %%
plt.scatter(Y_test,prediction)

# %%
accuracy_rate = []

# Will take some time
for i in range(1,40):
    
    knn = KNeighborsRegressor(n_neighbors=i)
    score=cross_val_score(knn,X,Y,cv=10,scoring="neg_mean_squared_error")
    accuracy_rate.append(score.mean())

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(range(1,40),accuracy_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
#plt.plot(range(1,40),accuracy_rate,color='blue', linestyle='dashed', marker='o',
 #        markerfacecolor='red', markersize=10)
plt.title('Accuracy Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy Rate')
# Out:
# Text(0, 0.5, 'Accuracy Rate')

# %%
# FIRST A QUICK COMPARISON TO OUR ORIGINAL K=1
knn = KNeighborsRegressor(n_neighbors=1)

knn.fit(X_train,Y_train)
predictions = knn.predict(X_test)

# %%
sns.distplot(Y_test-predictions)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PM2.5', ylabel='Density'>

# %%
plt.scatter(Y_test,predictions)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(Y_test, predictions))
print('MSE:', metrics.mean_squared_error(Y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
# Out:
# MAE: 56.41596638655462
# MSE: 7044.533613445378
# RMSE: 83.93171994809458

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

# %%
lasso=Lasso()
parameters={'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)

lasso_regressor.fit(X,Y)
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1125793.4692616845, tolerance: 507.2749055292259
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1072339.585036055, tolerance: 504.3443251184834
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1255019.734409503, tolerance: 563.7851104100946
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
prediction=lasso_regressor.predict(X_test)

# %%
sns.distplot(Y_test-prediction)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PM2.5', ylabel='Density'>

# %%
plt.scatter(Y_test,prediction)

# %%
print('MAE:', metrics.mean_absolute_error(Y_test, prediction))
print('MSE:', metrics.mean_squared_error(Y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(Y_test, prediction)))
# Out:
# MAE: 45.26895313769133
# MSE: 4252.1654019381795
# RMSE: 65.20862981184453

# %%
 print("Coefficient of determination R^2 <-- on trai{}".format(lasso_regressor.score(X_test, Y_test)))
# Out:
# Coefficient of determination R^2 <-- on trai-4252.1654019381795
